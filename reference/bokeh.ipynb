# %% [markdown]
# # 라이브러리

# %%
import pandas as pd
import re
import nltk
import itertools
import networkx as nx
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from collections import Counter

nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to /Users/master/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %% [markdown]
# # 데이터 로드

# %%
# data load
raw = pd.read_excel('/Users/master/dev/PythonPr/news-word_cloud/crawl_result_v.1.xlsx')
raw = raw[['title', 'body', 'url']]

# %% [markdown]
# ## 데이터 전처리

# %%
# text cleaning
raw['title'] = list(map(lambda x: re.sub('[^.,?!\s\w]','',x),raw['title']))
raw['body'] = list(map(lambda x: re.sub('[^.,?!\s\w]','',str(x)),raw['body']))

# case conversion
raw['title'] = list(map(lambda x: x.lower(), raw['title']))
raw['body'] = list(map(lambda x: x.lower(), raw['body']))

# %%
filtered_content = raw.copy()

# %% [markdown]
# # 토큰화

# %%
# Tokenization
full_body = ''.join(filtered_content['body'])
full_title = ''.join(filtered_content['title'])
full_text = ''.join([full_title, full_body])

word_tokens = nltk.word_tokenize(full_text)

# POS tagging
tokens_pos = nltk.pos_tag(word_tokens)

# select nouns
NN_words = []
for word, pos in tokens_pos:
    if 'NN' in pos:
        NN_words.append(word)
'''
# Lemmatization
wlem = nltk.WordNetLemmatizer()
lemmatized_words = []

for word in NN_words:
    new_word = wlem.lemmatize(word)
    lemmatized_words.append(new_word)
'''
# Out:
# '\n# Lemmatization\nwlem = nltk.WordNetLemmatizer()\nlemmatized_words = []\n\nfor word in NN_words:\n    new_word = wlem.lemmatize(word)\n    lemmatized_words.append(new_word)\n'

# %% [markdown]
# ## Stop words 정리

# %%
# Stopwords removal
# 1차적으로 nltk에서 제공하는 불용어사전을 이용해서 불용어를 제거

stopwords_list = stopwords.words('english') #nltk에서 제공하는 불용어사전 이용
unique_NN_words = set(NN_words)   #set을 사용해 중복 제거
final_NN_words = NN_words

for word in unique_NN_words:
    if word in stopwords_list:
        while word in final_NN_words: final_NN_words.remove(word)


# 아래와 같이 추가로 직접 만든 불용어사전을 이용해 불용어 제거
customized_stopwords = ['be', 'today', 'yesterday', 'new', 'york', 'time']  # 직접 만든 불용어 사전
unique_NN_words1 = set(final_NN_words)

for word in unique_NN_words1:
    if word in customized_stopwords:
        while word in final_NN_words: final_NN_words.remove(word)


## final_NN_words 출력해보기
print(final_NN_words)
# Out:
# ['intelligence', 'strengthens', 'alliance', 'roku.s', 'intelligence', 'barbecue', 'township', 'newsjin', 'kimchi', 'express', 'review', 'food', 'banchan', 'sengkangkfood', 'area', 'daesang', 'consumption', 'globallyeric', 'food', 'shortage', 'food', 'trader', 'joes', 'food', 'conglomerates', 'success', 'food', 'restaurants', 'delhincrperilla', 'kitchen', 'popup', 'dinner', 'life', 'metcalfes', 'things', 'food', 'newslarge', 'crowd', 'optimism', 'culture', 'presentationcj', 'youngs', 'business', 'food', 'truck', 'food', 'cesohsun', 'banchan', 'cafe', 'pioneer', 'square', 'food', 'lotus', 'star', 'crying', 'movie', 'adaptationseungwoo', 'bs', 'kimchi', 'gimbap', 'morestuttgart', 'eatery', 'plenty', 'food', 'cuisine', 'starplease', 'verify', 'brings', 'flavors', 'brunchchef', 'peter', 'serpico', 'starrs', 'kpod', 'menu', 'shifts', 'examples', 'dishes', 'korea', 'turkiyemichelin', 'chefs', 'cuisine', 'media', 'reports', 'bts', 'jimins', 'contribution', 'profits', 'samyang', 'foods', 'woman', 'zomatos', 'restaurant', 'trip', 'racist', 'voicemail', 'tv', 'anchor', 'kids', 'guide', 'restaurant', 'lands', 'beijingchas', 'market', 'kitchen', 'food', 'neighborhood', 'eatstourists', 'blizzard', 'kind', 'couple', 'home', 'weekendkpop', 'kicks', 'week', 'culture', 'aucklandno', 'shortcuts', 'chef', 'esther', 'choi', 'love', 'food3323', 'food', 'chain', 'bonchon', 'fan', 'favorites', 'dallasnorth', 'korea', 'hermit', 'food', 'runs', 'star', 'choi', 'woo', 'shik', 'bts', 'v', 'jinnys', 'size', 'chingu', 'restaurant', 'kc', 'food', 'brand', 'brand', 'storefront', 'baroo', 'experts', 'food', 'surveythe', 'burnthe', 'burnthanks', 'memories', 'resto', 'taste', 'food', 'closingowners', 'years', 'restaurant', 'experience', 'agrofisheries', 'food', 'trade', 'corp.', 'bases', 'kfood', 'expansiona', 'buzzy', 'banchan', 'popup', 'deli', 'pioneer', 'squareplease', 'humanmeet', 'woman', 'guide', 'restaurants', 'palisades', 'yorks', 'food', 'sceneanto', 'fine', 'dining', 'east', 'restaurants', 'birmingham', 'menus', 'k', 'food', 'bites', 'valley', 'foodtech', 'startup', 'chicken', 'robots', 'yorkkfood', 'area', 'paris', 'baguette', 'charms', 'taste', 'buds', 'food', 'trucks', 'side', 'waikele', 'additions', 'washington', 'greece', 'cookbooks', 'spring', 'eatery', 'food', 'barbecue', 'bridge', 'texas', 'knox', 'barbecue', 'monday', 'night', 'foodballnongshim', 'farm', 'infrastructure', 'arabiathousands', 'gather', 'food', 'culture', 'midautumn', 'moon', 'festivalchimaeks', 'food', 'selection', 'night', 'covingtonthe', 'bay', 'areas', 'food', 'scene', 'dishes', 'basics', 'food', 'simple', 'brand', 'yopokki', 'demand', 'snacks', 'america10', 'food', 'recipes', 'beginners', 'kimchi', 'group', 'appoints', 'jooyun', 'ceo', 'br', 'korea', 'co.is', 'restaurant', 'chain', 'jersey', 'winter', 'weather', 'food', 'insecurity', 'food', 'shortage', 'korea', 'cuisine', 'exportcelebrities', 'film', 'kfood', 'reality', 'showsrestaurants', 'triangle', 'secta9ine', 'scanner', 'food', 'beverage', 'industrychinas', 'exports', 'janfeb', 'shipmentsbroadview', 'magazinelees', 'pot', 'brings', 'cooking', 'right', 'tablefrybabys', 'hatch', 'heritage', 'chickenpress', 'release', 'food', 'stores', 'shore', 'malls', 'wage', 'hour', 'child', 'labor', 'law', 'food', 'stores', 'shore', 'malls', 'wage', 'hour', 'child', 'labor', 'law', 'recipesfine', 'specialists', 'role', 'haute', 'cuisine', 'reasons', 'show', 'jinnys', 'kitchen', 'food', 'security', 'development', 'strategylg', 'robots', 'food', 'atlanta', 'restaurants', 'food', 'companies', 'growth', 'engineskfood', 'area', 'pulmuone', 'targets', 'americans', 'lineupaspire', 'food', 'group', 'worlds', 'cricket', 'production', 'facility', 'scouts', 'sitespc', 'group', 'names', 'shilla', 'exec', 'pr', 'dishes', 'order', 'lover', 'food', 'explains', 'kimchisoul', 'moves', 'hotspot', 'sydney11', 'restaurants', 'franciscosookju', 'salad', 'sprouts', 'limelightusag', 'humphreys', 'intelligence', 'professionals', 'republic', 'korea', 'army' ...

# %% [markdown]
# # Semantic Network 형성

# %% [markdown]
# ### 최빈 단어 리스트 20개

# %%
c = Counter(final_NN_words)
list_of_words = []
for word, count in c.most_common(20):
    list_of_words.append(word)

print(f"가장 흔한 단어 20개: {list_of_words}")
# Out:
# 가장 흔한 단어 20개: ['food', 'rice', 'kimchi', 'restaurant', 'dishes', 'restaurants', 'korea', 'dish', 'years', 'menu', 'kim', 'people', 'market', 'chicken', 'year', 'cuisine', 'ingredients', 'life', 'sauce', 'products']

# %% [markdown]
# ### 문장 단위로 분리

# %%
# 원본 text 문장 단위로 쪼개기
sentences = full_text.split('\n')

def sentence_divide(target_symbol):
    result = []
    for sentence in sentences:
        result.extend(sentence.split(target_symbol))
    return result
sentences = sentence_divide('. ')
sentences = sentence_divide('!')
article_sentences = sentence_divide('?')

# %% [markdown]
# ### 관계를 DataFrame으로 정리

# %%
'''
for sentence in article_sentences:
    word_tokens = nltk.word_tokenize(sentence)
    tokens_pos = nltk.pos_tag(word_tokens)

    NN_words = []
    for word, pos in tokens_pos:
        if "NN" in pos:
            NN_words.append(word)

    selected_words = []
    for word in NN_words:
        if word in list_of_words:
            selected_words.append(word)
    
    selected_words = set(selected_words)

    for pair in list(itertools.combinations(list(selected_words), 2)):
        # itertools.combinations: selected_words 리스트에서 2개씩 골라 조합을 만들어준다.
'''
# Out:
# '\nfor sentence in article_sentences:\n    word_tokens = nltk.word_tokenize(sentence)\n    tokens_pos = nltk.pos_tag(word_tokens)\n\n    NN_words = []\n    for word, pos in tokens_pos:\n        if "NN" in pos:\n            NN_words.append(word)\n\n    selected_words = []\n    for word in NN_words:\n        if word in list_of_words:\n            selected_words.append(word)\n    \n    selected_words = set(selected_words)\n\n    for pair in list(itertools.combinations(list(selected_words), 2)):\n        # itertools.combinations: selected_words 리스트에서 2개씩 골라 조합을 만들어준다.\n'

# %%
sentence = article_sentences[0]


word_tokens = nltk.word_tokenize(sentence)
tokens_pos = nltk.pos_tag(word_tokens)

NN_words = []
for word, pos in tokens_pos:
    if "NN" in pos:
        NN_words.append(word)

selected_words = []
for word in NN_words:
    if word in list_of_words:
        selected_words.append(word)

selected_words = set(selected_words)

word_combo = list(itertools.combinations(list(selected_words), 2))
type(word_combo)
# Out:
# list

# %%
article_sentences[0]
# Out:
# '501st military intelligence brigade strengthens alliance by hosting roku.s'

# %% [markdown]
# # 수정

# %%
import pandas as pd
import re
import nltk
import itertools
import networkx as nx
import matplotlib.pyplot as plt

nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to /Users/master/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/master/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %% [markdown]
# ## 데이터 로드 및 소문자 변환

# %%
# data load
raw = pd.read_excel('/Users/master/dev/PythonPr/news-word_cloud/crawl_result_v.1.xlsx')
raw = raw[['title', 'body', 'url']]

# text cleaning
# raw['title'] = list(map(lambda x: re.sub('[^.,?!\s\w]','',x),raw['title']))
# raw['body'] = list(map(lambda x: re.sub('[^.,?!\s\w]','',str(x)),raw['body']))

# case conversion
raw['title'] = list(map(lambda x: x.lower(), raw['title']))
raw['body'] = list(map(lambda x:str(x).lower(), raw['body']))

filtered_content = raw.copy()

# %% [markdown]
# ## 유니크 명사 뽑기

# %%
# Tokenization
full_body = ''.join(filtered_content['body'])
full_title = ''.join(filtered_content['title'])
full_text = ''.join([full_title, full_body])

word_tokens = nltk.word_tokenize(full_text)

# POS tagging
tokens_pos = nltk.pos_tag(word_tokens)

# select nouns
NN_words = []
for word, pos in tokens_pos:
    if 'NN' in pos:
        NN_words.append(word)
unique_NN_words = list(set(NN_words))

# %% [markdown]
# ### Stop words 정리

# %%
stopwords_list = stopwords.words('english') #nltk에서 제공하는 불용어사전 이용
